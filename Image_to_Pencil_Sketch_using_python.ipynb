# %% [markdown]
# # **TASK-04 Image TO Pencil Sketch with python**

# %% [markdown]
# # **AUTHOR- MADHURI PRASAD**

# %% [markdown]
# # Importing necessary package

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread("bird.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x853 at 0x7F8EB825E610>

# %%
cv2.waitKey(0)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1280x853 at 0x7F8EB8256410>
# -1

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey()
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
# Out:
# <PIL.Image.Image image mode=L size=1280x853 at 0x7F8EB82D2310>

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1280x853 at 0x7F8EB82BDFD0>
# -1
